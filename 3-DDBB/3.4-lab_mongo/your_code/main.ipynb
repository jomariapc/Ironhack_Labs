# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# Importing libraries and setting up connection

# %%
import pandas as pd

# %%
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017')

# %%
db= client.companies

# %%
col= db.coleccion

# %%
df= pd.DataFrame(list(col.find()))

# %%
df.head(2)
# Out:
#                         _id       name permalink  \
# 0  52cdef7c4bab8bd675297d8a   Wetpaint      abc2
# 1  52cdef7c4bab8bd675297d8b  AdventNet      abc3
#
#                                 crunchbase_url             homepage_url  \
# 0   http://www.crunchbase.com/company/wetpaint  http://wetpaint-inc.com
# 1  http://www.crunchbase.com/company/adventnet     http://adventnet.com
#
#                       blog_url                     blog_feed_url  \
# 0  http://digitalquarters.net/  http://digitalquarters.net/feed/
# 1
#
#   twitter_username category_code  number_of_employees  ...  \
# 0  BachelrWetpaint           web                 47.0  ...
# 1     manageengine    enterprise                600.0  ...
#
#                                              offices  \
# 0  [{'description': '', 'address1': '710 - 2nd Av...
# 1  [{'description': 'Headquarters', 'address1': '...
#
#                                           milestones  video_embeds  \
# 0  [{'id': 5869, 'description': 'Wetpaint named i...            []
# 1                                                 []            []
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 86], 'assets/imag...
# 1  [{'available_sizes': [[[150, 94], 'assets/imag...
#
#                                       external_links partners  \
# 0  [{'external_url': 'http://www.geekwire.com/201...       []
# 1                                                 []       []
#
#   deadpooled_month deadpooled_day deadpooled_url  ipo
# 0              NaN            NaN            NaN  NaN
# 1              NaN            NaN            NaN  NaN
#
# [2 rows x 42 columns]

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
# Your Code

query={'name': 'Babelgum'}

select={'_id': 0, 'name': 1}

list(col.find(query, select))
# Out:
# [{'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
# Your Code
query={'number_of_employees': {'$gt': 5000}}

# %%
pipeline = [{'$match': query},
            {'$project': {'_id': 0,
                        'Name': '$name',
                        'Employees': '$number_of_employees' }},
            {'$sort': {'employees': -1}}, {'$limit': 5}]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#        Name  Employees
# 0    Yahoo!      13600
# 1    Google      28000
# 2      eBay      15000
# 3  Facebook       5299
# 4     Cisco      63000

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
# Your Code
query={'$and': [{'founded_year':  {'$gte': 2000}},
                {'founded_year':  {'$lte': 2005}}] }


pipeline = [{'$match': query},
            {'$project': {'_id': 0,
                        'Name': '$name',
                        'Founded year': '$founded_year' }}, {'$limit': 5}]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#         Name  Founded year
# 0   Wetpaint          2005
# 1       Zoho          2005
# 2       Digg          2004
# 3   Facebook          2004
# 4  Omnidrive          2005

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
# Your Code
query={ '$and': [{'ipo.valuation_amount':  {'$gt': 100000000}},
            {'founded_year':  {'$lte': 2010}}] }


pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'IPO': '$ipo' ,
                        'Valuation amount': '$valuation_amount',
                        'Valuation currency code': '$valuation_currency_code',
                        'Pub year': '$pub_year',
                        'Pub Month': '$pub_month',
                        'Stock Symbol': '$stock_symbol',
                        'Publication year': {'$concat': ['$pub_year', ' - ', '$pub_month']}}}, { '$limit': 3}]

#A que queda preciosa con el normalize? :D 
pd.json_normalize(list(col.aggregate(pipeline)))
# Out:
#        Name Publication year  IPO.valuation_amount  \
# 0  Facebook             None          1.040000e+11
# 1   Twitter             None          1.810000e+10
# 2      Yelp             None          1.300000e+09
#
#   IPO.valuation_currency_code  IPO.pub_year  IPO.pub_month  IPO.pub_day  \
# 0                         USD          2012              5           18
# 1                         USD          2013             11            7
# 2                         USD          2012              3            2
#
#   IPO.stock_symbol
# 0        NASDAQ:FB
# 1        NYSE:TWTR
# 2        NYSE:YELP

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
# Your Code
query={ '$and': [{'number_of_employees':  {'$lte': 1000}},
            {'founded_year':  {'$lte': 2005}}] }


pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'Number of employees': '$number_of_employees' ,
                        'Founded Year': '$founded_year'}}, { '$limit': 10}]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#                     Name  Number of employees  Founded Year
# 0               Wetpaint                   47          2005
# 1              AdventNet                  600          1996
# 2                   Digg                   60          2004
# 3  Fox Interactive Media                    0          1979
# 4                  Plaxo                   50          2002
# 5             Technorati                   35          2002
# 6                AddThis                  120          2004
# 7        Jingle Networks                   35          2005
# 8                 Meetup                   75          2002
# 9               LifeLock                  644          2005

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
# Your Code
query={"partners":{"$exists":"false"}} 


pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name'}}, { '$limit': 5}]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#         Name
# 0   Wetpaint
# 1  AdventNet
# 2       Zoho
# 3       Digg
# 4   Facebook

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
# Your Code
query={"category_code": { "$type": 10 }} 


pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'Category Code':'$category_code'}}, { '$limit': 5}]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#            Name Category Code
# 0    Collective          None
# 1       Snimmer          None
# 2        KoolIM          None
# 3  Level9 Media          None
# 4       VidKing          None

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
# Your Code
query={ '$and': [{'number_of_employees':  {'$lte': 1000}},
            {'number_of_employees':  {'$gt': 100}}] }


pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'Number of employees': '$number_of_employees'}}, { '$limit': 5}, {'$sort': {'number_of_employees': -1}}] 

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#         Name  Number of employees
# 0  AdventNet                  600
# 1    AddThis                  120
# 2      OpenX                  305
# 3   LifeLock                  644
# 4      Jajah                  110

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
# Your Code
pipeline = [{ '$project': {'_id': 0,
                        'Name': '$name'}}, { '$limit': 5}, {'$sort': {'IPO': -1}}] 

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#         Name
# 0   Wetpaint
# 1  AdventNet
# 2       Zoho
# 3       Digg
# 4   Facebook

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
# Your Code
query={ 'number_of_employees':  {'$gte': 1}}
pipeline = [{ '$match': query},{ '$project': {'_id': 0,
                        'Name': '$name',
                        'Number of employees': '$number_of_employees'}}, { '$limit': 5}, {'$sort': {'Number of employees': -1}}] 

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#         Name  Number of employees
# 0   Facebook                 5299
# 1       Zoho                 1600
# 2  AdventNet                  600
# 3       Digg                   60
# 4   Wetpaint                   47

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
# Your Code
query={ '$and': [{'founded_month':  {'$gt': 6}},
            {'founded_month':  {'$lte': 12}}] }

pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'Founded Month': '$founded_month' ,
                        'Founded Year': '$founded_year'}}, { '$limit': 10}, { '$sort': {'Founded Year': -1}}]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#         Name  Founded Month  Founded Year
# 0      Joost             10          2006
# 1   Powerset             10          2006
# 2       Kyte             12          2006
# 3      Thoof             12          2006
# 4   Wetpaint             10          2005
# 5       Zoho              9          2005
# 6  Omnidrive             11          2005
# 7       Digg             10          2004
# 8      Plaxo             11          2002
# 9       eBay              9          1995

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
# Your Code
query={ '$and': [{'founded_year':  {'$lte': 2000}},
            {'acquisition.price_amount':  {'$gte': 100000}}] }

pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'Founded Year': '$founded_year',
                        'Acquisition Amount': '$acquisition.price_amount'}}, { '$limit': 10}, { '$sort': {'Acquisition Amount': 1}}]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#                Name  Founded Year  Acquisition Amount
# 0           Cyworld          1999        7.140000e+06
# 1        Recipezaar          1999        2.500000e+07
# 2           Neopets          1999        1.600000e+08
# 3          SideStep          1999        1.800000e+08
# 4          Snapfish          1999        3.000000e+08
# 5           Postini          1999        6.250000e+08
# 6           Alibaba          1999        1.000000e+09
# 7            Zappos          1999        1.200000e+09
# 8            PayPal          1998        1.500000e+09
# 9  Sun Microsystems          1982        7.400000e+09

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
# Your Code
query={ '$and': [{'acquisition.acquired_year':  {'$gte': 2010}},
            {'acquisition.price_amount':  {'$ne': None}}] }



pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'Acquisition': '$acquisition'}
            }, { '$limit': 5}, { '$sort': {'Acquisition.price_amount': 1}}
           ]

pd.json_normalize(list(col.aggregate(pipeline)))
# Out:
#               Name  Acquisition.price_amount Acquisition.price_currency_code  \
# 0             Digg                    500000                             USD
# 1         Wetpaint                  30000000                             USD
# 2        Revision3                  30000000                             USD
# 3  Jingle Networks                  62500000                             USD
# 4         iContact                 169000000                             USD
#
#   Acquisition.term_code                             Acquisition.source_url  \
# 0                  None  http://techcrunch.com/2012/07/12/betaworks-acq...
# 1        cash_and_stock  http://allthingsd.com/20131216/viggle-tries-to...
# 2                  None  http://allthingsd.com/20120503/discovery-gets-...
# 3        cash_and_stock  http://www.masshightech.com/stories/2011/04/11...
# 4        cash_and_stock  http://techcrunch.com/2012/02/28/vocus-buys-em...
#
#                       Acquisition.source_description  \
# 0               Betaworks Acquires Digg (TechCrunch)
# 1   Viggle Tries to Bulk Up Its Social TV Busines...
# 2  Discovery Gets a Web Video Arm, Courtesy of Re...
# 3            Jingle Networks bought for up to $62.5M
# 4  Vocus Buys Email Marketing Company iContact Fo...
#
#    Acquisition.acquired_year  Acquisition.acquired_month  \
# 0                       2012                           7
# 1                       2013                          12
# 2                       2012                           5
# 3                       2011                           4
# 4                       2012                           2
#
#    Acquisition.acquired_day Acquisition.acquiring_company.name  \
# 0                        12                          betaworks
# 1                        16                             Viggle
# 2                         3           Discovery Communications
# 3                        11                            Marchex
# 4                        28                              Vocus
#
#   Acquisition.acquiring_company.permalink
# 0                               betaworks
# 1                                  viggle
# 2                 discoverycommunications
# 3                                 marchex
# 4                                   vocus

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
# Your Code
query={'founded_year':  {'$gt': 0}}

pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'Founded Year': '$founded_year'}}, { '$limit': 5}, { '$sort': {'Founded Year': 1}}]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#         Name  Founded Year
# 0  AdventNet          1996
# 1       Digg          2004
# 2   Facebook          2004
# 3   Wetpaint          2005
# 4       Zoho          2005

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
# Your Code
query={ '$and': [{'founded_day':  {'$lte': 7}},
                {'acquisition.price_amount':  {'$gt': 0}}]}



pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'Acquisition Price': '$acquisition.price_amount'}
            }, { '$limit': 5}, { '$sort': {'Acquisition Price': -1}}
           ]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#               Name  Acquisition Price
# 0          Postini          625000000
# 1            Jajah          207000000
# 2  Jingle Networks           62500000
# 3            Helio           39000000
# 4      StumbleUpon           29000000

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
# Your Code
query = {'$and': [{'category_code': 'web'},
                  {'number_of_employees': {'$gte': 4000}}]}

pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'Number of employees': '$number_of_employees',
                        'Category': '$category_code' }
            }, { '$limit': 5}, { '$sort': {'Number of employees': 1}}
           ]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#       Name  Number of employees Category
# 0      AOL                 8000      web
# 1  Webkinz                 8657      web
# 2  Rakuten                10000      web
# 3   Yahoo!                13600      web
# 4     eBay                15000      web

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
# Your Code
query = {'$and': [{'acquisition.price_amount': {'$gte': 10000000}},
                  {'acquisition.price_currency_code': 'EUR'}]}

pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'Acquisition Price Amount': '$acquisition.price_amount',
                        'Acquisition Price Currency Code': '$acquisition.price_currency_code' }
            }, { '$limit': 5}, { '$sort': {'Acquisition Price Amount': 1}}
           ]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#                 Name  Acquisition Price Amount Acquisition Price Currency Code
# 0          Wayfinder                  24000000                             EUR
# 1                ZYB                  31500000                             EUR
# 2  Greenfield Online                  40000000                             EUR
# 3            Webedia                  70000000                             EUR
# 4            Apertio                 140000000                             EUR

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
# Your Code
query={'$and': [{'acquisition.price_amount': {'$gt': 0}},
                  {'acquisition.acquired_month':  {'$lte': 3}}]}




pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'Acquisition': '$acquisition'}}, { '$limit': 5}, { '$sort': {'Acquisition.acquired_year': 1}}
           ]

pd.json_normalize(list(col.aggregate(pipeline)))
# Out:
#           Name  Acquisition.price_amount Acquisition.price_currency_code  \
# 0   NetRatings                 327000000                             USD
# 1       Revver                   5000000                             USD
# 2        Pluck                  75000000                             USD
# 3     iContact                 169000000                             USD
# 4  Dailymotion                 168000000                             USD
#
#   Acquisition.term_code                             Acquisition.source_url  \
# 0                  cash  http://login.vnuemedia.com/hr/login/login_subs...
# 1                  None  http://newteevee.com/2008/02/14/liveuniverse-b...
# 2                  cash  http://www.techcrunch.com/2008/03/04/demand-me...
# 3        cash_and_stock  http://techcrunch.com/2012/02/28/vocus-buys-em...
# 4                  None  http://techcrunch.com/2013/02/22/orange-acquir...
#
#                       Acquisition.source_description  \
# 0                    Nielsen buys rest of NetRatings
# 1  LiveUniverse Buys Revver for More than a Song ...
# 2            Demand Media Buys Pluck for $75 million
# 3  Vocus Buys Email Marketing Company iContact Fo...
# 4  Orange Acquired Dailymotion For $168 Million B...
#
#    Acquisition.acquired_year  Acquisition.acquired_month  \
# 0                       2007                           2
# 1                       2008                           2
# 2                       2008                           3
# 3                       2012                           2
# 4                       2013                           2
#
#    Acquisition.acquired_day Acquisition.acquiring_company.name  \
# 0                       NaN                            Nielsen
# 1                      14.0                       LiveUniverse
# 2                       4.0                       Demand Media
# 3                      28.0                              Vocus
# 4                      22.0                             Orange
#
#   Acquisition.acquiring_company.permalink
# 0                                 nielsen
# 1                            liveuniverse
# 2                             demandmedia
# 3                                   vocus
# 4                                  orange

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
# Your Code
query={'$and': [{'founded_year': {'$gte': 2000}},
                {'founded_year': {'$lte': 2010}},
                {'acquisition.acquired_year':  {'$gte': 2011}}]}


pipeline = [{ '$match': query},
            { '$project': {'_id': 0,
                        'Name': '$name',
                        'Founded Year': '$founded_year'}}, { '$limit': 5}, { '$sort': {'Founded Year': 1}}]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#               Name  Founded Year
# 0             Digg          2004
# 1         Wetpaint          2005
# 2  Jingle Networks          2005
# 3             Geni          2006
# 4             Kyte          2006

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
query = {
    '$and': [
        {'deadpooled_year': {'$gte': 1}},
        {'$expr': {'$gte': [{'$subtract': ['$deadpooled_year', '$founded_year']}, 3]}}
    ]
}

# %%
# Your Code

pipeline = [{ '$match': query},
            { '$project': 
             {'_id': 0,
                        'Name': '$name',
                        'Founded Year': '$founded_year'}}, { '$limit': 5}, { '$sort': {'Founded Year': 1}}]

pd.DataFrame(list(col.aggregate(pipeline)))
# Out:
#         Name  Founded Year
# 0  Omnidrive          2005
# 1     Wesabe          2005
# 2  Jangl SMS          2005
# 3      Thoof          2006
# 4   Babelgum          2007
